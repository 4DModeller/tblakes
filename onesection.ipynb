# %%
import rasterio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
geotiff_path = 'EarthEngineData2/Difference_2012_0.tif'
with rasterio.open(geotiff_path) as src:
    data = src.read(1)  # Reading the first band
    nodata = src.nodata
    print(data.shape)
# Out:
# (70, 100)

# %%
plt.pcolormesh(data[:,])
plt.colorbar()
